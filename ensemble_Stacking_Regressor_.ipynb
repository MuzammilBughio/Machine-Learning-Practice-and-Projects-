# %% [markdown]
# <a href="https://colab.research.google.com/github/MuzammilBughio/Machine-Learning-Practice-and-Projects-/blob/main/ensemble_Stacking_Regressor_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.metrics import  r2_score

# %%
X , y = make_regression(n_samples = 500 , n_features = 20 , n_informative=12 , noise = 0.1)
X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

lr = LinearRegression()
svr = SVR()
dtr = DecisionTreeRegressor(max_depth=3)

# %%
estimator_list = [ None , lr , svr , dtr ] # None is RidgeCV (default)
for final_est in estimator_list:
  vr = StackingRegressor([
      ('lr' , lr),
      ('svr' , svr),
      ('dtr' , dtr)
  ] ,
    final_estimator=final_est
                      )

  vr.fit(X_train , y_train)

  y_pred = vr.predict(X_test)

  print(f'final est { "RidgeCV" if final_est is None else final_est } ,r2 score : ' , r2_score(y_test , y_pred ))
# Out:
# final est RidgeCV ,r2 score :  0.9999998023773262
# final est LinearRegression() ,r2 score :  0.9999998023591578
# final est SVR() ,r2 score :  0.39349522758668665
# final est DecisionTreeRegressor(max_depth=3) ,r2 score :  0.9627205299368842
